# %% [markdown]
# # Same seed, same random numbers

# %%
import random

# %%
random.seed(99)
xs = []
for _ in range(5):
    xs.append(random.randint(1, 100))
xs
# Out:
# [52, 49, 26, 77, 23]

# %%
random.seed(99)
ys = []
for _ in range(5):
    ys.append(random.randint(1, 100))
ys
# Out:
# [52, 49, 26, 77, 23]

# %%
random.seed(7)
zs = []
for _ in range(5):
    zs.append(random.randint(1, 100))
zs
# Out:
# [42, 20, 51, 84, 7]
